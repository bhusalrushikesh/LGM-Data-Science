# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.6.0.66-cp36-abi3-win_amd64.whl (35.6 MB)
#      ---------------------------------------- 35.6/35.6 MB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.19.3 in c:\users\public\lgm\env\lib\site-packages (from opencv-python) (1.22.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.6.0.66
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
import numpy as np

# %% [markdown]
# ## Read image

# %%
image = cv2.imread("dog-wolf.jpg")
image
# Out:
# array([[[228, 204, 180],
#         [228, 204, 180],
#         [228, 204, 180],
#         ...,
#         [242, 226, 210],
#         [242, 226, 210],
#         [242, 226, 210]],
#
#        [[228, 204, 180],
#         [228, 204, 180],
#         [229, 205, 181],
#         ...,
#         [242, 226, 210],
#         [242, 226, 210],
#         [242, 226, 210]],
#
#        [[228, 204, 180],
#         [229, 205, 181],
#         [229, 205, 181],
#         ...,
#         [241, 225, 209],
#         [241, 225, 209],
#         [241, 225, 209]],
#
#        ...,
#
#        [[229, 206, 184],
#         [229, 206, 184],
#         [229, 206, 184],
#         ...,
#         [231, 211, 194],
#         [231, 211, 194],
#         [232, 212, 195]],
#
#        [[230, 207, 185],
#         [230, 207, 185],
#         [230, 207, 185],
#         ...,
#         [231, 211, 194],
#         [231, 211, 194],
#         [231, 211, 194]],
#
#        [[230, 207, 185],
#         [230, 207, 185],
#         [230, 207, 185],
#         ...,
#         [230, 210, 193],
#         [230, 210, 193],
#         [230, 210, 193]]], dtype=uint8)

# %% [markdown]
# ## Dispaly Image

# %%
cv2.imshow("Diksha", image)
cv2.waitKey(0)
# Out:
# -1

# %%
## Read Image as RGB

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ## Converting the original image to Greyscale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[200, 200, 200, ..., 223, 223, 223],
#        [200, 200, 201, ..., 223, 223, 223],
#        [200, 201, 201, ..., 222, 222, 222],
#        ...,
#        [202, 202, 202, ..., 208, 208, 209],
#        [203, 203, 203, ..., 208, 208, 208],
#        [203, 203, 203, ..., 207, 207, 207]], dtype=uint8)

# %%
plt.imshow(gray_image)

# %% [markdown]
# ## Inverting Image

# %%
inverted_image = 255 - gray_image 
#inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# ## Blur the image by using the Gaussian Function

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)
plt.imshow(blurred)

# %% [markdown]
# ## Invert the blurred image for final image(pencil sketch)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(pencil_sketch)

# %% [markdown]
# ## Final Skech

# %%
cv2.imshow("Diksha Sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ## Original image and the pencil sketch

# %%
cv2.imshow("original image", image)
cv2.imshow("pencil sketch", pencil_sketch)
cv2.waitKey(0)
# Out:
# -1
